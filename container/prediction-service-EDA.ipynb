# %%
import pandas as pd
import pickle
import _pickle as cPickle

# %% [markdown]
# # Fetch data from ucirepo, heart disease data

# %%
from ucimlrepo import fetch_ucirepo

# %%
# fetch dataset 
heart_disease = fetch_ucirepo(id=45)

# %%
dataset = heart_disease["data"]["features"]
dataset["num"] = heart_disease["data"]["targets"]
dataset.to_csv("data/heart_disease_dataset.csv")

# %% [markdown]
# # Load data

# %%
dataset = pd.read_csv("data/heart_disease_dataset.csv", index_col=0)

# %%
dataset
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   1       145   233    1        2      150      0      2.3
# 1     67    1   4       160   286    0        2      108      1      1.5
# 2     67    1   4       120   229    0        2      129      1      2.6
# 3     37    1   3       130   250    0        0      187      0      3.5
# 4     41    0   2       130   204    0        2      172      0      1.4
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   45    1   1       110   264    0        0      132      0      1.2
# 299   68    1   4       144   193    1        0      141      0      3.4
# 300   57    1   4       130   131    0        0      115      1      1.2
# 301   57    0   2       130   236    0        2      174      0      0.0
# 302   38    1   3       138   175    0        0      173      0      0.0
#
#      slope   ca  thal  num
# 0        3  0.0   6.0    0
# 1        2  3.0   3.0    2
# ...
